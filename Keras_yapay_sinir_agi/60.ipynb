# %%
import numpy as np 
import matplotlib.pyplot as plt
import  random

from keras.models import Sequential
from keras.layers import  Dense, Dropout, Activation, Flatten
from keras import regularizers
from keras.preprocessing.image import  ImageDataGenerator
import os
from keras.callbacks import  EarlyStopping

from numpy import expand_dims
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Out:
# Found 1672 images belonging to 6 classes.
# Found 206 images belonging to 6 classes.
# Found 509 images belonging to 6 classes.

# %%
print("class_indices:",train_generator.class_indices)
print("class_mode:",val_generator.class_mode)
print("classes:",val_generator.classes)

# %%
train_path='/content/drive/MyDrive/Deep Learning/odev_Dataset/train/'
test_path='/content/drive/MyDrive/Deep Learning/odev_Dataset/test'

train_datagen=ImageDataGenerator(
    rescale=1./255,
    rotation_range=0.5,         
    zoom_range=0.1,        
    horizontal_flip=True,   
    validation_split=0.2
)
val_datagen=ImageDataGenerator(rescale=1./255, validation_split=0.1) #%10 istendi
test_datagen=ImageDataGenerator(rescale=1./255)


x,y=(64,64) #image widht,height
train_generator=train_datagen.flow_from_directory(
    train_path,
    target_size=(x,y),         
    class_mode='categorical',  
    batch_size=128,        
    subset='training'    
)

val_generator=val_datagen.flow_from_directory( 
    train_path,
    target_size=(x,y),
    shuffle=False,
    class_mode='categorical',
    batch_size=128,
    subset='validation'
)


test_generator=test_datagen.flow_from_directory( 
    test_path,
    target_size=(x,y),
    shuffle=True,
    class_mode='categorical',
    batch_size=1    
)



plt.figure(figsize=(10,10))

for i in range(6):
  img,y=test_generator.next()
  plt.subplot(2,3,i+1)
  plt.axis('off')
  plt.title(list(y[:195][0]).index(1))
  plt.imshow(img[0])
# Out:
# Found 1672 images belonging to 6 classes.
# Found 206 images belonging to 6 classes.
# Found 509 images belonging to 6 classes.

# %%
model=Sequential()
model.add(Flatten(input_shape=(64,64,3)))

model.add(Dense(64,activation='relu'))
model.add(Dense(64,activation='relu'))

model.add(Dense(6,activation='softmax'))

model.compile(loss="categorical_crossentropy",optimizer="adam",metrics=['accuracy'])

model.summary()

history=model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples//128,
    validation_data=val_generator,
    epochs=100,
    validation_steps=val_generator.samples//128
)
# Out:
# Model: "sequential_51"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_51 (Flatten)         (None, 12288)             0
# _________________________________________________________________
# dense_151 (Dense)            (None, 64)                786496
# _________________________________________________________________
# dense_152 (Dense)            (None, 64)                4160
# _________________________________________________________________
# dense_153 (Dense)            (None, 6)                 390
# =================================================================
# Total params: 791,046
# Trainable params: 791,046
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 13/13 [==============================] - 12s 950ms/step - loss: 3.9487 - accuracy: 0.1917 - val_loss: 1.5913 - val_accuracy: 0.2422
# Epoch 2/100
# 13/13 [==============================] - 11s 835ms/step - loss: 1.7585 - accuracy: 0.2563 - val_loss: 1.5681 - val_accuracy: 0.3203
# Epoch 3/100
# 13/13 [==============================] - 11s 842ms/step - loss: 1.6364 - accuracy: 0.3547 - val_loss: 1.8944 - val_accuracy: 0.1484
# Epoch 4/100
# 13/13 [==============================] - 11s 838ms/step - loss: 1.6212 - accuracy: 0.3634 - val_loss: 2.3340 - val_accuracy: 0.0312
# Epoch 5/100
# 13/13 [==============================] - 11s 840ms/step - loss: 1.7214 - accuracy: 0.3240 - val_loss: 1.4889 - val_accuracy: 0.4844
# Epoch 6/100
# 13/13 [==============================] - 11s 868ms/step - loss: 1.2446 - accuracy: 0.5040 - val_loss: 1.2572 - val_accuracy: 0.4844
# Epoch 64/100
# 13/13 [==============================] - 11s 863ms/step - loss: 1.2829 - accuracy: 0.4875 - val_loss: 1.4826 - val_accuracy: 0.3750
# Epoch 65/100
# 13/13 [==============================] - 11s 884ms/step - loss: 1.2476 - accuracy: 0.5272 - val_loss: 1.5693 - val_accuracy: 0.3750
# Epoch 66/100
# 13/13 [==============================] - 12s 900ms/step - loss: 1.2314 - accuracy: 0.5172 - val_loss: 1.3256 - val_accuracy: 0.4609
# Epoch 67/100
# 13/13 [==============================] - 11s 931ms/step - loss: 1.2814 - accuracy: 0.4967 - val_loss: 1.3220 - val_accuracy: 0.5156
# Epoch 68/100
# 13/13 [==============================] - 11s 872ms/step - loss: 1.1993 - accuracy: 0.5342 - val_loss: 1.3299 - val_accuracy: 0.4844
# Epoch 69/100
# 13/13 [==============================] - 11s 867ms/step - loss: 1.1947 - accuracy: 0.5148 - val_loss: 1.5201 - val_accuracy: 0.4141
# Epoch 70/100
# 13/13 [==============================] - 11s 871ms/step - loss: 1.2654 - accuracy: 0.5120 - val_loss: 1.3906 - val_accuracy: 0.4375
# Epoch 71/100
# 13/13 [==============================] - 11s 856ms/step - loss: 1.1468 - accuracy: 0.5630 - val_loss: 1.3491 - val_accuracy: 0.4844
# Epoch 72/100
# 13/13 [==============================] - 11s 887ms/step - loss: 1.1662 - accuracy: 0.5479 - val_loss: 1.4903 - val_accuracy: 0.4375
# Epoch 73/100
# 13/13 [==============================] - 12s 923ms/step - loss: 1.2164 - accuracy: 0.5212 - val_loss: 1.5103 - val_accuracy: 0.3672
# Epoch 74/100
# 13/13 [==============================] - 12s 891ms/step - loss: 1.1780 - accuracy: 0.5323 - val_loss: 1.3555 - val_accuracy: 0.4453
# Epoch 75/100
# 13/13 [==============================] - 11s 846ms/step - loss: 1.2246 - accuracy: 0.5216 - val_loss: 1.2462 - val_accuracy: 0.5547
# Epoch 76/100
# 13/13 [==============================] - 11s 830ms/step - loss: 1.1601 - accuracy: 0.5484 - val_loss: 1.3304 - val_accuracy: 0.4766
# Epoch 77/100
# 13/13 [==============================] - 11s 850ms/step - loss: 1.1484 - accuracy: 0.5489 - val_loss: 1.2811 - val_accuracy: 0.5156
# Epoch 78/100
# 13/13 [==============================] - 11s 857ms/step - loss: 1.1176 - accuracy: 0.5671 - val_loss: 1.4858 - val_accuracy: 0.4375
# Epoch 79/100
# 13/13 [==============================] - 11s 849ms/step - loss: 1.1604 - accuracy: 0.5437 - val_loss: 1.3002 - val_accuracy: 0.4844
# Epoch 80/100
# 13/13 [==============================] - 11s 916ms/step - loss: 1.3837 - accuracy: 0.4630 - val_loss: 1.5244 - val_accuracy: 0.3828
# Epoch 81/100
# 13/13 [==============================] - 11s 852ms/step - loss: 1.1699 - accuracy: 0.5480 - val_loss: 1.2731 - val_accuracy: 0.5547
# Epoch 82/100
# 13/13 [==============================] - 11s 866ms/step - loss: 1.1729 - accuracy: 0.5398 - val_loss: 1.3874 - val_accuracy: 0.4453
# Epoch 83/100
# 13/13 [==============================] - 11s 859ms/step - loss: 1.1402 - accuracy: 0.5421 - val_loss: 1.2973 - val_accuracy: 0.5156
# Epoch 84/100
# 13/13 [==============================] - 11s 868ms/step - loss: 1.1433 - accuracy: 0.5524 - val_loss: 1.5204 - val_accuracy: 0.3984
# Epoch 85/100
# 13/13 [==============================] - 11s 857ms/step - loss: 1.1491 - accuracy: 0.5601 - val_loss: 1.5161 - val_accuracy: 0.3984
# Epoch 86/100
# 13/13 [==============================] - 11s 882ms/step - loss: 1.1388 - accuracy: 0.5613 - val_loss: 1.3466 - val_accuracy: 0.4922
# Epoch 87/100
# 13/13 [==============================] - 11s 842ms/step - loss: 1.0740 - accuracy: 0.5826 - val_loss: 1.3865 - val_accuracy: 0.4766
# Epoch 88/100
# 13/13 [==============================] - 11s 873ms/step - loss: 1.2114 - accuracy: 0.5164 - val_loss: 1.6772 - val_accuracy: 0.4219
# Epoch 89/100
# 13/13 [==============================] - 12s 894ms/step - loss: 1.2542 - accuracy: 0.4952 - val_loss: 1.2729 - val_accuracy: 0.5391
# Epoch 90/100
# 13/13 [==============================] - 11s 886ms/step - loss: 1.2075 - accuracy: 0.5325 - val_loss: 1.4409 - val_accuracy: 0.4531
# Epoch 91/100
# 13/13 [==============================] - 11s 940ms/step - loss: 1.2366 - accuracy: 0.5033 - val_loss: 1.3478 - val_accuracy: 0.4922
# Epoch 92/100
# 13/13 [==============================] - 11s 853ms/step - loss: 1.1291 - accuracy: 0.5801 - val_loss: 1.3727 - val_accuracy: 0.4922
# Epoch 93/100
# 13/13 [==============================] - 11s 942ms/step - loss: 1.1887 - accuracy: 0.5406 - val_loss: 1.4667 - val_accuracy: 0.4141
# Epoch 94/100
# 13/13 [==============================] - 12s 894ms/step - loss: 1.1210 - accuracy: 0.5667 - val_loss: 1.4424 - val_accuracy: 0.3906
# Epoch 95/100
# 13/13 [==============================] - 12s 889ms/step - loss: 1.1125 - accuracy: 0.5657 - val_loss: 1.1804 - val_accuracy: 0.5859
# Epoch 96/100
# 13/13 [==============================] - 11s 850ms/step - loss: 1.0921 - accuracy: 0.5701 - val_loss: 1.4282 - val_accuracy: 0.4531
# Epoch 97/100
# 13/13 [==============================] - 11s 843ms/step - loss: 1.2132 - accuracy: 0.5238 - val_loss: 1.6204 - val_accuracy: 0.3828
# Epoch 98/100
# 13/13 [==============================] - 11s 851ms/step - loss: 1.0905 - accuracy: 0.5919 - val_loss: 1.2706 - val_accuracy: 0.4609
# Epoch 99/100
# 13/13 [==============================] - 11s 853ms/step - loss: 1.1333 - accuracy: 0.5631 - val_loss: 1.3198 - val_accuracy: 0.4609
# Epoch 100/100
# 13/13 [==============================] - 12s 899ms/step - loss: 1.0828 - accuracy: 0.5864 - val_loss: 1.4487 - val_accuracy: 0.4453

# %%
#Plot the Loss Curves
plt.figure(figsize=[8,6])
plt.plot(history.history['loss'],'r',linewidth=3.0)
plt.plot(history.history['val_loss'],'b',linewidth=3.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Loss',fontsize=16)
plt.title('Loss Curves',fontsize=16)

#Plot the Accuracy Curves
plt.figure(figsize=[8,6])
plt.plot(history.history['accuracy'],'r',linewidth=3.0)
plt.plot(history.history['val_accuracy'],'b',linewidth=3.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Accuracy',fontsize=16)
plt.title('Accuracy Curves',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Accuracy Curves')
